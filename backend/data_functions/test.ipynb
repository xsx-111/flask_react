# %%
import csv
import os
import re

def get_filelist(dir):
    Filelist = []
    for home, dirs, files in os.walk(dir):
        for filename in files:
            Filelist.append(os.path.join(home, filename))

    return Filelist


path='./data/all_songs_lyrics'
Filelist = get_filelist(path)

whole_lyrics = []
song_num = 0

with open('data/sentences.csv','w',encoding='utf-8', newline='') as f2:
    writer = csv.writer(f2)
    writer.writerow(['Sentence','Song_id','Song_name'])
    
for file in Filelist[1:]:
    song_num += 1
    song_id = f"s{song_num}"
    with open(file,'r',encoding='utf-8') as f1:
        content = f1.readlines()
        if len(content) == 0:
            continue

        song_name=file.split('/')[-1][:-4]

        if " Lyrics" in content[0]:
            content[0] = content[0].split(" Lyrics")[1]

        for i,line in enumerate(content):
            if line == "\n" or len(line) == 0 or line == '\t':
                continue

            if i == len(content)-1:
                line = re.split('[0-9]*Embed', line)[0]

            with open('data/sentences.csv','a',encoding='utf-8', newline='') as f2:
                writer = csv.writer(f2)
                writer.writerow([line.strip('\n'), song_id, song_name])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3a58ddb705ee> in <module>
#      42                 line = re.split('[0-9]*Embed', line)[0]
#      43
# ---> 44             with open('data/sentences_t.csv','a',encoding='utf-8', newline='') as f2:
#      45                 writer = csv.writer(f2)
#      46                 writer.writerow([line.strip('\n'), song_id, song_name])
#
# ~/opt/anaconda3/lib/python3.8/codecs.py in __init__(self, errors)
#     184     remembers the state of the encoding process between calls to encode().
#     185     """
# --> 186     def __init__(self, errors='strict'):
#     187         """
#     188         Creates an IncrementalEncoder instance.
#
# KeyboardInterrupt:

# %%
import string
import pandas as pd
import os
import re
import requests
import csv

# !pip install git+git://github.com/dbeley/rymscraper.git@master
# !pip install git+https://github.com/johnwmillr/LyricsGenius.git
import lyricsgenius
from bs4 import BeautifulSoup
from pathlib import Path

import pandas as pd
from rymscraper import rymscraper, RymUrl

network = rymscraper.RymNetwork()

client_access_token = "Ob87cTycMnGhXLCozaho1Ow0IWJZGT5iy_Xk7_3TTXz5tstLYjFeVXemNQkKEHQkX82uJotzT_sgjWSfhWtMgw"

def get_album_info(album_name, artist_name):
    LyricsGenius = lyricsgenius.Genius(client_access_token, timeout=10, retries = 3)
    LyricsGenius.remove_section_headers = True

    info = [album_name]

    try:
        album_object = LyricsGenius.search_album(album_name, artist_name)
        date_object = album_object.release_date_components
        date = f"{date_object.year}-{date_object.month}-{date_object.day}"
        info.append(date)
    except:
        info.append("")

    try:
        info.append(album_object.cover_art_thumbnail_url)
    except:
        info.append("")

    return info


def get_genres(artist, album):
    try:
        album_infos = network.get_album_infos(name=f"{artist} - {album}")
        return album_infos['Genres'].split('\n')[0]
    except:
        pass

    try:
        artist = artist.lower().replace(' ', '-')
        album = album.lower().replace(' ', '-')
        album_infos = network.get_album_infos(url=f"https://rateyourmusic.com/release/album/{artist}/{album}/")
        return album_infos['Genres'].split('\n')[0]
    except:
        return ""


with open('./data/songs_info.csv','w',encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["song_id", "song_name", "artist_name", "album_name", "release_date", "album_cover_url", "genres"])

album_list = []
with open('./data/songs_list.csv','r',encoding='utf-8') as csvreader:
    reader = csv.reader(csvreader)
    next(reader)
    for row in reader:
        song_id = row[0]
        song_name = row[1]
        artist_name = row[2]
        album_name = row[3]
        print(song_id)
        song_info = [song_id, song_name, artist_name]
        if album_name not in album_list:
            album_list.append(album_name)
            album_info = get_album_info(album_name, artist_name)
            album_info.append(get_genres(artist_name,album_name))

        song_info.extend(album_info)
        with open('./data/songs_info.csv','a',encoding='utf-8', newline='') as csvwriter:
            writer = csv.writer(csvwriter)
            writer.writerow(song_info)
# Out:
# Collecting git+git://github.com/dbeley/rymscraper.git@master
#   Cloning git://github.com/dbeley/rymscraper.git (to revision master) to /private/var/folders/m_/t0002n3n31jbzj617qsswsqc0000gn/T/pip-req-build-fep0emib
#   Running command git clone -q git://github.com/dbeley/rymscraper.git /private/var/folders/m_/t0002n3n31jbzj617qsswsqc0000gn/T/pip-req-build-fep0emib
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from rymscraper==0.2.2) (2.25.1)
# Requirement already satisfied: pandas in /Users/wenxing/miniconda3/lib/python3.9/site-packages/pandas-1.4.1-py3.9-macosx-10.9-x86_64.egg (from rymscraper==0.2.2) (1.4.1)
# Requirement already satisfied: beautifulsoup4 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from rymscraper==0.2.2) (4.10.0)
# Requirement already satisfied: tqdm in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from rymscraper==0.2.2) (4.61.2)
# Requirement already satisfied: lxml in /Users/wenxing/miniconda3/lib/python3.9/site-packages/lxml-4.7.1-py3.9-macosx-10.9-x86_64.egg (from rymscraper==0.2.2) (4.7.1)
# Requirement already satisfied: selenium in /Users/wenxing/miniconda3/lib/python3.9/site-packages/selenium-4.1.0-py3.9.egg (from rymscraper==0.2.2) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from beautifulsoup4->rymscraper==0.2.2) (2.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from pandas->rymscraper==0.2.2) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from pandas->rymscraper==0.2.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/wenxing/miniconda3/lib/python3.9/site-packages/pytz-2021.3-py3.9.egg (from pandas->rymscraper==0.2.2) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->rymscraper==0.2.2) (1.16.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests->rymscraper==0.2.2) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests->rymscraper==0.2.2) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests->rymscraper==0.2.2) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests->rymscraper==0.2.2) (1.26.6)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/wenxing/miniconda3/lib/python3.9/site-packages/trio_websocket-0.9.2-py3.9.egg (from selenium->rymscraper==0.2.2) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /Users/wenxing/miniconda3/lib/python3.9/site-packages/trio-0.19.0-py3.9.egg (from selenium->rymscraper==0.2.2) (0.19.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/wenxing/miniconda3/lib/python3.9/site-packages/async_generator-1.10-py3.9.egg (from trio~=0.17->selenium->rymscraper==0.2.2) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /Users/wenxing/miniconda3/lib/python3.9/site-packages/attrs-21.4.0-py3.9.egg (from trio~=0.17->selenium->rymscraper==0.2.2) (21.4.0)
# Requirement already satisfied: outcome in /Users/wenxing/miniconda3/lib/python3.9/site-packages/outcome-1.1.0-py3.9.egg (from trio~=0.17->selenium->rymscraper==0.2.2) (1.1.0)
# Requirement already satisfied: sniffio in /Users/wenxing/miniconda3/lib/python3.9/site-packages/sniffio-1.2.0-py3.9.egg (from trio~=0.17->selenium->rymscraper==0.2.2) (1.2.0)
# Requirement already satisfied: sortedcontainers in /Users/wenxing/miniconda3/lib/python3.9/site-packages/sortedcontainers-2.4.0-py3.9.egg (from trio~=0.17->selenium->rymscraper==0.2.2) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/wenxing/miniconda3/lib/python3.9/site-packages/wsproto-1.0.0-py3.9.egg (from trio-websocket~=0.9->selenium->rymscraper==0.2.2) (1.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from urllib3<1.27,>=1.21.1->requests->rymscraper==0.2.2) (3.4.7)
# Requirement already satisfied: pyOpenSSL>=0.14 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from urllib3<1.27,>=1.21.1->requests->rymscraper==0.2.2) (20.0.1)
# Requirement already satisfied: cffi>=1.12 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from cryptography>=1.3.4->urllib3<1.27,>=1.21.1->requests->rymscraper==0.2.2) (1.14.6)
# Requirement already satisfied: pycparser in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3<1.27,>=1.21.1->requests->rymscraper==0.2.2) (2.20)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/wenxing/miniconda3/lib/python3.9/site-packages/h11-0.13.0-py3.9.egg (from wsproto>=0.14->trio-websocket~=0.9->selenium->rymscraper==0.2.2) (0.13.0)
# Collecting git+https://github.com/johnwmillr/LyricsGenius.git
#   Cloning https://github.com/johnwmillr/LyricsGenius.git to /private/var/folders/m_/t0002n3n31jbzj617qsswsqc0000gn/T/pip-req-build-ankz_l18
#   Running command git clone -q https://github.com/johnwmillr/LyricsGenius.git /private/var/folders/m_/t0002n3n31jbzj617qsswsqc0000gn/T/pip-req-build-ankz_l18
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from lyricsgenius==3.0.1) (4.10.0)
# Requirement already satisfied: requests>=2.20.0 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from lyricsgenius==3.0.1) (2.25.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.6.0->lyricsgenius==3.0.1) (2.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests>=2.20.0->lyricsgenius==3.0.1) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests>=2.20.0->lyricsgenius==3.0.1) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests>=2.20.0->lyricsgenius==3.0.1) (1.26.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/wenxing/miniconda3/lib/python3.9/site-packages (from requests>=2.20.0->lyricsgenius==3.0.1) (4.0.0)
# s1
# Searching for "Wild Is The Wind" by Nina Simone...
# s2
# s3
# s4
# s5
# s6
# s7
# s8
# s9
# Searching for "Give Up The Ghost" by Brandi Carlile...
# s10
# s11
# s12
# s13
# s14
# s15
# s16
# s17
# s18
# s19
# s20
# Searching for "DiCaprio 2" by J.I.D...
# s21
# s22
# s23
# s24
# s25
# s26
# s27
# s28
# s29
# s30
# s31
# s32
# s33
# s34
# Searching for "Heartleap" by Vashti Bunyan...
# s35
# s36
# s37
# s38
# s39
# s40
# s41
# s42
# s43
# s44
# Searching for "Group Sex" by Circle Jerks...
# s45
# s46
# s47
# s48
# s49
# s50
# s51
# s52
# s53
# s54
# s55
# s56
# Searching for "Absolution" by Muse...
# s57
# s58
# s59
# s60
# s61
# s62
# s63
# s64
# s65
# s66
# s67
# s68
# s69
# s70
# s71
# Searching for "After Laughter" by Paramore...
# s72
# s73
# s74
# s75
# s76
# s77
# s78
# s79
# s80
# s81
# s82
# s83
# Searching for "25" by Adele...
# s84
# s85
# s86
# s87
# s88
# s89
# s90
# s91
# s92
# s93
# s94
# Searching for "Argybargy" by Squeeze...
# s95
# s96
# s97
# s98
# s99
# s100
# s101
# s102
# s103
# Searching for "The Places You Have Come To Fear The Most" by Dashboard Confessional...
# s104
# s105
# s106
# s107
# s108
# s109
# s110
# s111
# s112
# s113
# Searching for "Gold Mother" by James...
# s114
# s115
# s116
# s117
# s118
# s119
# s120
# s121
# s122
# s123
# s124
# s125
# Searching for "Congratulations" by MGMT...
# s126
# s127
# s128
# s129
# s130
# s131
# s132
# Searching for "Blackfield" by Blackfield...
# s133
# s134
# s135
# s136
# s137
# s138
# s139
# s140
# s141
# s142
# s143
# s144
# Searching for "Fuzzy Logic" by Super Furry Animals...
# s145
# s146
# s147
# s148
# s149
# s150
# s151
# s152
# s153
# s154
# Searching for "Lazaretto" by Jack White...
# s155
# s156
# s157
# s158
# s159
# s160
# s161
# s162
# s163
# s164
# s165
# Searching for "Universal Themes" by Sun Kil Moon...
# s166
# s167
# s168
# s169
# s170
# s171
# s172
# Searching for "Red House Painters (Bridge)" by Red House Painters...
# s173
# s174
# s175
# s176
# s177
# s178
# s179
# s180
# Searching for "Mellow Yellow" by Donovan...
# s181
# s182
# s183
# s184
# s185
# s186
# s187
# s188
# s189
# s190
# s191
# s192
# s193
# Searching for "Wide Open Spaces" by Dixie Chicks...
# s194
# s195
# s196
# s197
# s198
# s199
# Searching for "Blink-182" by Blink-182...
# s200
# s201
# s202
# s203
# s204
# s205
# s206
# s207
# s208
# s209
# s210
# s211
# s212
# s213
# s214
# Searching for "Floss" by Injury Reserve...
# s215
# s216
# s217
# s218
# s219
# s220
# s221
# s222
# s223
# s224
# Searching for "Legacy Of Brutality" by Misfits...
# s225
# s226
# s227
# s228
# s229
# s230
# s231
# s232
# s233
# s234
# s235
# s236
# s237
# Searching for "V2" by The Vibrators...
# s238
# s239
# s240
# s241
# s242
# s243
# s244
# s245
# s246
# s247
# s248
# s249
# s250
# s251
# Searching for "The Power To Believe" by King Crimson...
# s252
# s253
# s254
# s255
# s256
# s257
# s258
# s259
# s260
# s261
# s262
# Searching for "The Harder They Come" by Various Artists...
# s263
# s264
# s265
# s266
# s267
# s268
# s269
# s270
# s271
# s272
# Searching for "Hair Of The Dog" by Nazareth...
# s273
# s274
# s275
# s276
# s277
# s278
# s279
# s280
# Searching for "Rickie Lee Jones" by Rickie Lee Jones...
# s281
# s282
# s283
# s284
# s285
# s286
# s287
# s288
# s289
# Searching for "Louise Attaque" by Louise Attaque...
# s290
# s291
# s292
# s293
# s294
# s295
# s296
# s297
# s298
# s299
# Searching for "It's A Shame About Ray" by The Lemonheads...
# s300
# s301
# s302
# s303
# s304
# s305
# s306
# s307
# s308
# s309
# s310
# s311
# s312
# s313
# s314
# s315
# Searching for "Watermark" by Enya...
# s316
# s317
# s318
# s319
# s320
# s321
# s322
# s323
# s324
# s325
# s326
# s327
# s328
# Searching for "Disintegration" by The Cure...
# s329
# s330
# s331
# s332
# s333
# s334
# s335
# s336
# s337
# s338
# s339
# s340
# Searching for "One Way Ticket To Hell... And Back" by The Darkness...
# s341
# s342
# s343
# s344
# s345
# s346
# s347
# s348
# s349
# s350
# s351
# s352
# s353
# s354
# Searching for "Clumsy" by Our Lady Peace...
# s355
# s356
# s357
# s358
# s359
# s360
# s361
# s362
# s363
# s364
# Searching for "Ambient 1: Music For Airports" by Brian Eno...
# s365
# s366
# s367
# s368
# Searching for "Filth Pig" by Ministry...
# s369
# s370
# s371
# s372
# s373
# s374
# s375
# s376
# s377
# s378
# Searching for "The Monkees" by The Monkees...

# %%
import pandas as pd
alllyrics=pd.read_csv("./data/sentences.csv")
df=alllyrics.dropna(subset=['Sentence'])
df=df.reset_index(drop=True)
df.to_csv('./data/sentences.csv',index=False)

# %%
from tqdm import tqdm
import pandas as pd 


data = pd.read_csv("./data/songs_info.csv")
alllyrics=pd.read_csv('./data/sentences.csv') 
alllyrics
lyrics_dict={}

for songid in tqdm(data['song_id']):
    lyrics_dict[songid]=list(alllyrics[alllyrics['Song_id']==songid]['Sentence'])

df=data
df['lyrics'] = df['song_id'].map(lyrics_dict) 
df['album_cover_url'] = df['album_cover_url'].fillna("https://p.turbosquid.com/ts-thumb/jO/8hrD0I/WY/247vinyl_phonograph_record0001/jpg/1640965984/300x300/sharp_fit_q85/386c57a9f06bac781219d6b6e3a7b72a785bbebe/247vinyl_phonograph_record0001.jpg")
df['release_date'] = df['release_date'].fillna("UNKNOWN")
df['genres'] = df['genres'].fillna("UNKNOWN")
df.to_json ('./data/songs_info.json',orient='records')
# Out:
# 100%|██████████| 94902/94902 [4:20:39<00:00,  6.07it/s]

# %%
os.chdir('/Users/wenxing/TTDS/flask_react/backend/data_functions')

# %%
df['album_cover_url'].fillna("https://p.turbosquid.com/ts-thumb/jO/8hrD0I/WY/247vinyl_phonograph_record0001/jpg/1640965984/300x300/sharp_fit_q85/386c57a9f06bac781219d6b6e3a7b72a785bbebe/247vinyl_phonograph_record0001.jpg")
# Out:
# 0      https://images.genius.com/c77b77422e8463582a6f...
# 1      https://images.genius.com/c77b77422e8463582a6f...
# 2      https://images.genius.com/c77b77422e8463582a6f...
# 3      https://images.genius.com/c77b77422e8463582a6f...
# 4      https://images.genius.com/c77b77422e8463582a6f...
#                              ...
# 416    https://p.turbosquid.com/ts-thumb/jO/8hrD0I/WY...
# 417    https://p.turbosquid.com/ts-thumb/jO/8hrD0I/WY...
# 418    https://p.turbosquid.com/ts-thumb/jO/8hrD0I/WY...
# 419    https://p.turbosquid.com/ts-thumb/jO/8hrD0I/WY...
# 420    https://p.turbosquid.com/ts-thumb/jO/8hrD0I/WY...
# Name: album_cover_url, Length: 421, dtype: object

# %%
df
# Out:
#     song_id                      song_name  artist_name        album_name  \
# 0        s1                     Four Women  Nina Simone  Wild Is The Wind
# 1        s2  Why Keep On Breaking My Heart  Nina Simone  Wild Is The Wind
# 2        s3  Break Down and Let It All Out  Nina Simone  Wild Is The Wind
# 3        s4            What More Can I Say  Nina Simone  Wild Is The Wind
# 4        s5           If I Should Lose You  Nina Simone  Wild Is The Wind
# ..      ...                            ...          ...               ...
# 416    s417                 Tear Drop City  The Monkees       The Monkees
# 417    s418                 Star Collector  The Monkees       The Monkees
# 418    s419                  She Hangs Out  The Monkees       The Monkees
# 419    s420                       Oh My My  The Monkees       The Monkees
# 420    s421               Randy Scouse Git  The Monkees       The Monkees
#
#     release_date                                    album_cover_url  \
# 0      1966-9-16  https://images.genius.com/c77b77422e8463582a6f...
# 1      1966-9-16  https://images.genius.com/c77b77422e8463582a6f...
# 2      1966-9-16  https://images.genius.com/c77b77422e8463582a6f...
# 3      1966-9-16  https://images.genius.com/c77b77422e8463582a6f...
# 4      1966-9-16  https://images.genius.com/c77b77422e8463582a6f...
# ..           ...                                                ...
# 416          NaN                                                NaN
# 417          NaN                                                NaN
# 418          NaN                                                NaN
# 419          NaN                                                NaN
# 420          NaN                                                NaN
#
#                genres                                             lyrics
# 0    Vocal Jazz, Soul  [My skin is black, My arms are long, My hair i...
# 1    Vocal Jazz, Soul  [Why keep on breaking my heart, When it's beat...
# 2    Vocal Jazz, Soul  [Break down and let it all out, Break down and...
# 3    Vocal Jazz, Soul  [I would do anything, anything you say, If you...
# 4    Vocal Jazz, Soul  [If I should lose you, The stars would fall fr...
# ..                ...                                                ...
# 416               NaN  ['Bout as low as I've felt in a long time, And...
# 417               NaN  [(Oh) Hello, Think I'll let her keep on goin',...
# 418               NaN  [(Do the ronde ronde do the rond rond), How ol...
# 419               NaN  [Oh my my, I could love you forever, Oh my my,...
# 420               NaN  [{Intro}, She's a wonderful lady, And she's mi...
#
# [421 rows x 8 columns]

# %%
df['release_date'] = df['release_date'].fillna("UNKNOWN")

# %%
df['lyrics'][200]
# Out:
# ["My dearest, I've missed you very, very much since that last night we were together and will hold that night especially in my memories for years to come. I've been turning it over and over in my mind lately. I've read your letter through at least four times, and will probably read it more times before I'm through. I've been sitting here, looking at your picture, and getting more homesick every minute. I've wanted that picture more than anything else I know of except, of course, you yourself. I keep thinking of you, darling, keep wishing I could be home with you. I want to leave in the worse possible way so I can come home to see you, but things don't look so good in that subject. This war has spoiled a lot of things for everyone, I guess. I've never been so lonesome in my life as I am right now. I'm completely lost without you, darling. I never realized I could miss any one person so much. I just hope it won't be too much longer till I'm able to be with you again and live a sane and normal life."]

# %%
os.chdir('/Users/wenxing/TTDS/flask_react/backend/index_generator')
import sys
sys.path.append("..")
print(os.getcwd())
import database_functions
# os.chdir(sys.path+'/data_functions/data')
# print(os.getcwd())
with open('../data_functions/data/songs_list.csv') as ff:
    a = ff.readlines()
# Out:
# /Users/wenxing/TTDS/flask_react/backend/index_generator

# %%
sys.path
# Out:
# ['/Users/wenxing/TTDS/flask_react/backend/data_functions',
#  '/Users/wenxing/opt/anaconda3/lib/python38.zip',
#  '/Users/wenxing/opt/anaconda3/lib/python3.8',
#  '/Users/wenxing/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/Users/wenxing/.local/lib/python3.8/site-packages',
#  '/Users/wenxing/opt/anaconda3/lib/python3.8/site-packages',
#  '/Users/wenxing/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/Users/wenxing/opt/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg',
#  '/Users/wenxing/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/wenxing/.ipython',
#  '..',
#  '..',
#  '/data_functions/data',
#  '..',
#  '/data_functions/data',
#  '..',
#  '/data_functions/data',
#  '..',
#  '..',
#  '..',
#  '..']

# %%
import pandas as pd
from tqdm import tqdm
import os
import sys
sys.path.append("..")
import preprocessing

data = pd.read_json("./data/songs_info.json")
data.head(5)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/wenxing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/wenxing/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#   song_id                      song_name  artist_name        album_name  \
# 0      s1                     Four Women  Nina Simone  Wild Is The Wind
# 1      s2  Why Keep On Breaking My Heart  Nina Simone  Wild Is The Wind
# 2      s3  Break Down and Let It All Out  Nina Simone  Wild Is The Wind
# 3      s4            What More Can I Say  Nina Simone  Wild Is The Wind
# 4      s5           If I Should Lose You  Nina Simone  Wild Is The Wind
#
#   release_date                                    album_cover_url  \
# 0    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 1    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 2    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 3    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 4    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
#
#              genres                                             lyrics
# 0  Vocal Jazz, Soul  [My skin is black, My arms are long, My hair i...
# 1  Vocal Jazz, Soul  [Why keep on breaking my heart, When it's beat...
# 2  Vocal Jazz, Soul  [Break down and let it all out, Break down and...
# 3  Vocal Jazz, Soul  [I would do anything, anything you say, If you...
# 4  Vocal Jazz, Soul  [If I should lose you, The stars would fall fr...

# %%
preprocessing.preprocess(sentence, stemming=self.activate_stemming, stop=self.activate_stop)

# %%
data["song_name_preprocess"] = data.song_name.map(preprocessing.preprocess)

# %%
data["artist_name_preprocess"] = data.artist_name.map(preprocessing.preprocess)

# %%
data["album_name_preprocess"] = data.album_name.map(preprocessing.preprocess)

# %%
data.head(5)
# Out:
#   song_id                      song_name  artist_name        album_name  \
# 0      s1                     Four Women  Nina Simone  Wild Is The Wind
# 1      s2  Why Keep On Breaking My Heart  Nina Simone  Wild Is The Wind
# 2      s3  Break Down and Let It All Out  Nina Simone  Wild Is The Wind
# 3      s4            What More Can I Say  Nina Simone  Wild Is The Wind
# 4      s5           If I Should Lose You  Nina Simone  Wild Is The Wind
#
#   release_date                                    album_cover_url  \
# 0    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 1    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 2    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 3    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
# 4    1966/9/16  https://images.genius.com/c77b77422e8463582a6f...
#
#              genres                                             lyrics  \
# 0  Vocal Jazz, Soul  [My skin is black, My arms are long, My hair i...
# 1  Vocal Jazz, Soul  [Why keep on breaking my heart, When it's beat...
# 2  Vocal Jazz, Soul  [Break down and let it all out, Break down and...
# 3  Vocal Jazz, Soul  [I would do anything, anything you say, If you...
# 4  Vocal Jazz, Soul  [If I should lose you, The stars would fall fr...
#
#                     song_name_preprocess artist_name_preprocess  \
# 0                          [four, women]          [nina, simon]
# 1      [whi, keep, on, break, my, heart]          [nina, simon]
# 2  [break, down, and, let, it, all, out]          [nina, simon]
# 3              [what, more, can, i, say]          [nina, simon]
# 4             [if, i, should, lose, you]          [nina, simon]
#
#    album_name_preprocess
# 0  [wild, is, the, wind]
# 1  [wild, is, the, wind]
# 2  [wild, is, the, wind]
# 3  [wild, is, the, wind]
# 4  [wild, is, the, wind]

# %%
df = data

# %%
df.to_json ('./data/songs_info.json',orient='records')
